# %%
from google.colab import files
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score
from  sklearn.model_selection import train_test_split
import pandas as pd

files = files.upload()
# Out:
#      <input type="file" id="files-c9804295-bd96-4a4d-a41c-fb7313b522fd" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c9804295-bd96-4a4d-a41c-fb7313b522fd">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
read = pd.read_csv('patient_priorityRev1 - patient_priorityRev1 (1).csv')

#Load the dataset and display the first 10 rows.
read.head(10)
# Out:
#    Unnamed: 0   age  gender  chest pain type  blood pressure  cholesterol  \
# 0           0  40.0    male                2             140          294
# 1           1  49.0  female                3             160          180
# 2           2  37.0    male                2             130          294
# 3           3  48.0  female                4             138          214
# 4           4  54.0    male                3             150          195
# 5           5  39.0    male                3             120          294
# 6           6  45.0  female                2             130          237
# 7           7  54.0    male                2             110          208
# 8           8  37.0    male                4             140          207
# 9           9  48.0  female                2             120          294
#
#    max heart rate  hypertension  heart_disease Residence_type smoking_status  \
# ...

# %%
#Check all for missing values. If any, handle them appropriately. for gender , age , hypertension, triage, residence_type
print("Before : ", read.isnull().sum())
handling = read['heart_disease'].mean()
read['heart_disease'] = read['heart_disease'].fillna(handling)
read.dropna(subset=['gender', 'age', 'hypertension', 'triage', 'Residence_type'], inplace=True)
print("\nAfter : ",read.isnull().sum())
# Out:
# Before :  Unnamed: 0         0
# age                0
# gender             0
# chest pain type    0
# blood pressure     0
# cholesterol        0
# max heart rate     0
# hypertension       0
# heart_disease      0
# Residence_type     0
# smoking_status     0
# triage             0
# dtype: int64
#
# After :  Unnamed: 0         0
# age                0
# gender             0
# chest pain type    0
# blood pressure     0
# cholesterol        0
# max heart rate     0
# hypertension       0
# heart_disease      0
# Residence_type     0
# smoking_status     0
# triage             0
# dtype: int64

# %%
#Encode categorical variables: gender, chest_pain_type , hypertension, heart Disease , Residence_Type , Smoking_status


categories = read[['gender','chest pain type','hypertension','heart_disease','Residence_type','smoking_status']]

print(categories.head(5))
# Out:
#    gender  chest pain type  hypertension  heart_disease Residence_type  \
# 0    male                2           0.0            0.0          Urban
# 1  female                3           0.0            0.0          Urban
# 2    male                2           0.0            0.0          Urban
# 3  female                4           1.0            0.0          Urban
# 4    male                3           0.0            0.0          Urban
#
#   smoking_status
# 0   never smoked
# 1   never smoked
# 2         smoked
# 3         smoked
# 4   never smoked

# %%
#Get to know the data by performing exploratory data analysis using any of the following: measures of central tendency, variability, percentile, and quartiles of age,
#cholesterol, and max heart rate. Provide data analysis based on the results

numerical_cols = ['age', 'cholesterol', 'max heart rate']


wews = read[numerical_cols].describe(percentiles=[.25, .5, .75])


display(wews)
# Out:
#               age  cholesterol  max heart rate
# count  316.000000   316.000000      316.000000
# mean    49.772152   231.598101      156.196203
# std      9.335645    47.055454       12.798045
# min     28.000000   150.000000      139.000000
# 25%     43.000000   182.000000      146.000000
# 50%     50.000000   224.000000      150.000000
# 75%     55.000000   294.000000      166.250000
# max     81.000000   294.000000      190.000000

# %%
#(Normalize numerical variables (age, blood pressure, cholesterol, max heart rate)
from sklearn.preprocessing import StandardScaler

numerical_cols = ['age','blood pressure','cholesterol','max heart rate']
scaler = StandardScaler()
read[numerical_cols] = scaler.fit_transform(read[numerical_cols])

# %%
from sklearn.model_selection import train_test_split


x = read.drop('triage', axis=1)
y = read['triage']


x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

print("Shape of x_train:", x_train.shape)
print("Shape of x_test:", x_test.shape)
print("Shape of y_train:", y_train.shape)
print("Shape of y_test:", y_test.shape)
# Out:
# Shape of x_train: (252, 11)
# Shape of x_test: (64, 11)
# Shape of y_train: (252,)
# Shape of y_test: (64,)
