# %%
from google.colab import files
import pandas as pd



data = {

        'Course': ['BSCS', 'BSCOE', 'BSBA','BSCRIM','BSNR'],
        'Score': [1,5,2,34,612]



}

framed = pd.DataFrame(data)
asd = data['Score'].plot(kind = 'hist')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-5-eace24bcb797> in <cell line: 16>()
#      14
#      15 framed = pd.DataFrame(data)
# ---> 16 asd = data['Score'].plot(kind = 'hist')
#
# AttributeError: 'list' object has no attribute 'plot'
