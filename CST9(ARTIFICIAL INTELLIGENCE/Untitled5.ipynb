# %%
import pandas as pd
from google.colab import files

file1  = files.upload()
# Out:
#      <input type="file" id="files-a3d0f528-3a74-4524-9d17-7a6001f8745c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a3d0f528-3a74-4524-9d17-7a6001f8745c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
readcsv = pd.read_csv('HarryPotterGrades Dataset with Null - HarryPotterGrades Dataset with Null.csv')
print(readcsv)
# Out:
#                   Name  Potions  Defense Against the Dark Arts  \
# 0         Harry Potter       85                           92.0
# 1     Hermione Granger       91                           90.0
# 2          Ron Weasley       92                           86.0
# 3         Draco Malfoy       84                           80.0
# 4   Neville Longbottom       89                           84.0
# 5          Dean Thomas       84                           84.0
# 6      Seamus Finnigan       91                           86.0
# 7       Lavender Brown       83                           83.0
# 8         Fred Weasley       90                           80.0
# 9          Oliver Wood       76                            NaN
# 10          Katie Bell       75                           88.0
# 11       Parvati Patil       90                           85.0
# 12        Romilda Vane       75                           78.0
# 13       Luna Lovegood       80                           81.0
# ...

# %%
from sklearn.impute import SimpleImputer
import numpy as np


filteringNumberColumns  = readcsv.select_dtypes(include=[np.number]).columns
importingImputer = SimpleImputer(strategy='mean')
file1[filteringNumberColumns] = importingImputer.fit_transform(file1[filteringNumberColumns])


print(filteringNumberColumns)
# Out:
# Index(['Potions', 'Defense Against the Dark Arts', 'Care of Magical Creatures',
#        'Transfiguration', 'Herbology'],
#       dtype='object')
